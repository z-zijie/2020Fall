# %%
import pandas as pd
data = pd.read_csv('titanic_data.csv')
Data = data.drop(['Survived'], axis=1).values
y_label = data['Survived'].values

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 2)
clf = clf.fit(Data, y_label)
tree.plot_tree(clf)
# Out:
# [Text(167.4, 181.2, 'X[1] <= 0.5\nentropy = 0.962\nsamples = 887\nvalue = [545, 342]'),
#  Text(83.7, 108.72, 'X[2] <= 13.0\nentropy = 0.702\nsamples = 573\nvalue = [464, 109]'),
#  Text(41.85, 36.23999999999998, 'entropy = 0.989\nsamples = 41\nvalue = [18, 23]'),
#  Text(125.55000000000001, 36.23999999999998, 'entropy = 0.638\nsamples = 532\nvalue = [446, 86]'),
#  Text(251.10000000000002, 108.72, 'X[0] <= 2.5\nentropy = 0.824\nsamples = 314\nvalue = [81, 233]'),
#  Text(209.25, 36.23999999999998, 'entropy = 0.299\nsamples = 170\nvalue = [9, 161]'),
#  Text(292.95, 36.23999999999998, 'entropy = 1.0\nsamples = 144\nvalue = [72, 72]')]

# %%
# Out:
# array([ 1,  2, -2, -2,  0, -2, -2], dtype=int64)

# %%
Data = data.drop(['Survived'], axis=1)
y_label = data['Survived']
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 3)
clf = clf.fit(Data, y_label)
tree.plot_tree(clf)
# Out:
# [Text(167.4, 190.26, 'X[1] <= 0.5\nentropy = 0.962\nsamples = 887\nvalue = [545, 342]'),
#  Text(83.7, 135.9, 'X[2] <= 13.0\nentropy = 0.702\nsamples = 573\nvalue = [464, 109]'),
#  Text(41.85, 81.53999999999999, 'X[3] <= 2.5\nentropy = 0.989\nsamples = 41\nvalue = [18, 23]'),
#  Text(20.925, 27.180000000000007, 'entropy = 0.258\nsamples = 23\nvalue = [1, 22]'),
#  Text(62.775000000000006, 27.180000000000007, 'entropy = 0.31\nsamples = 18\nvalue = [17, 1]'),
#  Text(125.55000000000001, 81.53999999999999, 'X[5] <= 26.269\nentropy = 0.638\nsamples = 532\nvalue = [446, 86]'),
#  Text(104.625, 27.180000000000007, 'entropy = 0.467\nsamples = 393\nvalue = [354, 39]'),
#  Text(146.475, 27.180000000000007, 'entropy = 0.923\nsamples = 139\nvalue = [92, 47]'),
#  Text(251.10000000000002, 135.9, 'X[0] <= 2.5\nentropy = 0.824\nsamples = 314\nvalue = [81, 233]'),
#  Text(209.25, 81.53999999999999, 'X[5] <= 28.856\nentropy = 0.299\nsamples = 170\nvalue = [9, 161]'),
#  Text(188.32500000000002, 27.180000000000007, 'entropy = 0.469\nsamples = 70\nvalue = [7, 63]'),
#  Text(230.175, 27.180000000000007, 'entropy = 0.141\nsamples = 100\nvalue = [2, 98]'),
#  Text(292.95, 81.53999999999999, 'X[5] <= 23.35\nentropy = 1.0\nsamples = 144\nvalue = [72, 72]'),
#  Text(272.02500000000003, 27.180000000000007, 'entropy = 0.977\nsamples = 117\nvalue = [48, 69]'),
#  Text(313.875, 27.180000000000007, 'entropy = 0.503\nsamples = 27\nvalue = [24, 3]')]
